# %% [markdown]
# #HW1_Huang_Kuan

# %% [markdown]
# #Data Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from pandas.core.reshape.reshape import get_dummies
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

# %%
# Read data file
# Preprocess data file by setting ID as index
df = pd.read_csv("HW1_house_price_regression.csv",index_col=0)
df
# Out:
# ...
#       MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# Id                                      ...
# 1             60       RL         65.0  ...        WD        Normal    208500
# 2             20       RL         80.0  ...        WD        Normal    181500
# 3             60       RL         68.0  ...        WD        Normal    223500
# 4             70       RL         60.0  ...        WD       Abnorml    140000
# 5             60       RL         84.0  ...        WD        Normal    250000
# ...          ...      ...          ...  ...       ...           ...       ...
# 1456          60       RL         62.0  ...        WD        Normal    175000
# 1457          20       RL         85.0  ...        WD        Normal    210000
# 1458          70       RL         66.0  ...        WD        Normal    266500
# 1459          20       RL         68.0  ...        WD        Normal    142125
# ...

# %%
# Display type and keys of dict
print("Type of %s dataset: %s" % ("housing", type(df)))
print("Keys: %s" % df.keys)
print("Keys: %s" % df.keys())
# Out:
# Type of housing dataset: <class 'pandas.core.frame.DataFrame'>
# Keys: <bound method NDFrame.keys of       MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# Id                                      ...
# 1             60       RL         65.0  ...        WD        Normal    208500
# 2             20       RL         80.0  ...        WD        Normal    181500
# 3             60       RL         68.0  ...        WD        Normal    223500
# 4             70       RL         60.0  ...        WD       Abnorml    140000
# 5             60       RL         84.0  ...        WD        Normal    250000
# ...          ...      ...          ...  ...       ...           ...       ...
# 1456          60       RL         62.0  ...        WD        Normal    175000
# 1457          20       RL         85.0  ...        WD        Normal    210000
# 1458          70       RL         66.0  ...        WD        Normal    266500
# ...

# %%
# Display SalePrice
print("Sale Price: %s" % df["SalePrice"])
# Out:
# Sale Price: Id
# 1       208500
# 2       181500
# 3       223500
# 4       140000
# 5       250000
#          ...
# 1456    175000
# 1457    210000
# 1458    266500
# 1459    142125
# 1460    147500
# Name: SalePrice, Length: 1460, dtype: int64

# %%
# Interactive dataframe
from google.colab import data_table
data_table.enable_dataframe_formatter()
df.head(20000)
# Out:
# ...
#       MSSubClass MSZoning  LotFrontage  ...  SaleType SaleCondition SalePrice
# Id                                      ...
# 1             60       RL         65.0  ...        WD        Normal    208500
# 2             20       RL         80.0  ...        WD        Normal    181500
# 3             60       RL         68.0  ...        WD        Normal    223500
# 4             70       RL         60.0  ...        WD       Abnorml    140000
# 5             60       RL         84.0  ...        WD        Normal    250000
# ...          ...      ...          ...  ...       ...           ...       ...
# 1456          60       RL         62.0  ...        WD        Normal    175000
# 1457          20       RL         85.0  ...        WD        Normal    210000
# 1458          70       RL         66.0  ...        WD        Normal    266500
# 1459          20       RL         68.0  ...        WD        Normal    142125
# ...

# %%
# Check for missing values in columns
df.isnull().sum()
# Out:
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
# Street             0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 80, dtype: int64

# %%
# Report data types of columns
df.dtypes
# Out:
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
#                   ...
# MoSold             int64
# YrSold             int64
# SaleType          object
# SaleCondition     object
# SalePrice          int64
# Length: 80, dtype: object

# %%
# Report descriptive statistics
df.describe()
# Out:
# ...
#         MSSubClass  LotFrontage  ...       YrSold      SalePrice
# count  1460.000000  1201.000000  ...  1460.000000    1460.000000
# mean     56.897260    70.049958  ...  2007.815753  180921.195890
# std      42.300571    24.284752  ...     1.328095   79442.502883
# min      20.000000    21.000000  ...  2006.000000   34900.000000
# 25%      20.000000    59.000000  ...  2007.000000  129975.000000
# 50%      50.000000    69.000000  ...  2008.000000  163000.000000
# 75%      70.000000    80.000000  ...  2009.000000  214000.000000
# max     190.000000   313.000000  ...  2010.000000  755000.000000
#
# [8 rows x 37 columns]

# %% [markdown]
# # Visualization

# %%
# Display histogram on sale price in MatPlotLib
plt.figure(figsize=(8,8))
plt.xlabel("Sale Price Distribution")
plt.ylabel("Count")
plt.title("Sale Price")
df.SalePrice.hist(bins=20)

# %%
# Correlation matrix
df.corr('pearson')
# Out:
# ...
#                MSSubClass  LotFrontage   LotArea  ...    MoSold    YrSold  SalePrice
# MSSubClass       1.000000    -0.386347 -0.139781  ... -0.013585 -0.021407  -0.084284
# LotFrontage     -0.386347     1.000000  0.426095  ...  0.011200  0.007450   0.351799
# LotArea         -0.139781     0.426095  1.000000  ...  0.001205 -0.014261   0.263843
# OverallQual      0.032628     0.251646  0.105806  ...  0.070815 -0.027347   0.790982
# OverallCond     -0.059316    -0.059213 -0.005636  ... -0.003511  0.043950  -0.077856
# YearBuilt        0.027850     0.123349  0.014228  ...  0.012398 -0.013618   0.522897
# YearRemodAdd     0.040581     0.088866  0.013788  ...  0.021490  0.035743   0.507101
# MasVnrArea       0.022936     0.193458  0.104160  ... -0.005965 -0.008201   0.477493
# BsmtFinSF1      -0.069836     0.233633  0.214103  ... -0.015727  0.014359   0.386420
# BsmtFinSF2      -0.065649     0.049900  0.111170  ... -0.015211  0.031706  -0.011378
# ...

# %%
# Display correlation heatmap in Seaborn(one and only one figure)
plt.figure(figsize=(30, 30))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap', fontdict={'fontsize':12}, pad=12)
# Out:
# Text(0.5, 1.0, 'Correlation Heatmap')

# %% [markdown]
# ###Select numerical variables with high correlation in the heatmap and select categorical variables. Then merge both into a new data frame.

# %%
# Based on the heatmap above to select numeric variables with high correlation
df.num = df[['SalePrice', 'YearBuilt', 'TotalBsmtSF', 'GrLivArea', 'FullBath','TotRmsAbvGrd', 'GarageCars']]

# Select categorical variables
df.cat = df[['Street', 'LandContour', 'LandSlope', 'HouseStyle', 'RoofStyle', 'MasVnrType', 'Foundation', 'BsmtQual', 'Heating', 'Functional']]

# Make a new data frame
df1 = pd.merge(df.cat, df.num, on = 'Id')
df1.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   """
#    Street LandContour LandSlope  ... FullBath TotRmsAbvGrd GarageCars
# Id                               ...
# 1    Pave         Lvl       Gtl  ...        2            8          2
# 2    Pave         Lvl       Gtl  ...        2            6          2
# 3    Pave         Lvl       Gtl  ...        2            6          2
# 4    Pave         Lvl       Gtl  ...        1            7          3
# 5    Pave         Lvl       Gtl  ...        2            9          3
#
# [5 rows x 17 columns]

# %%
# Get dummy variables
df1 = get_dummies(df1)
df1
# Out:
# ...
#       SalePrice  YearBuilt  ...  Functional_Sev  Functional_Typ
# Id                          ...
# 1        208500       2003  ...               0               1
# 2        181500       1976  ...               0               1
# 3        223500       2001  ...               0               1
# 4        140000       1915  ...               0               1
# 5        250000       2000  ...               0               1
# ...         ...        ...  ...             ...             ...
# 1456     175000       1999  ...               0               1
# 1457     210000       1978  ...               0               0
# 1458     266500       1941  ...               0               1
# 1459     142125       1950  ...               0               1
# 1460     147500       1965  ...               0               1
#
# [1460 rows x 57 columns]

# %% [markdown]
# # Create training and validation sets

# %%
#Set training data set and the target
df_train = df1.iloc[:, 1:]
df_target = df1.iloc[:, 0]
print("Before:\nData = %s\nTarget = %s" % (df_train.shape,df_target.shape))

# Split the data and target into training and validation sets
data_train, data_valid, target_train, target_valid = train_test_split(df_train, df_target, test_size=0.3, random_state=0)

# Verify sizes
print("After:\nTraining Data = %s\nValidation Data = %s" % (data_train.shape, data_valid.shape))
print("Training Target = %s\nValidation Target = %s" % (target_train.shape, target_valid.shape))
# Out:
# Before:
# Data = (1460, 56)
# Target = (1460,)
# After:
# Training Data = (1022, 56)
# Validation Data = (438, 56)
# Training Target = (1022,)
# Validation Target = (438,)

# %% [markdown]
# # ML Modeling
# Multiple Linear Regression (MLR)

# %%
# Create mlr model
mlr = LinearRegression()
# Fit the training data
mlr.fit(data_train, target_train)
# Out:
# LinearRegression()

# %%
print("Variables = %s" % data_train.columns.tolist())
print("Coefficients = %s" % mlr.coef_)
print("Intercept = %f" % mlr.intercept_)
print("R2 for training = %.5f" % mlr.score(data_train, target_train))
print("R2 for validation = %.5f" % mlr.score(data_valid, target_valid))
# Out:
# Variables = ['YearBuilt', 'TotalBsmtSF', 'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'Street_Grvl', 'Street_Pave', 'LandContour_Bnk', 'LandContour_HLS', 'LandContour_Low', 'LandContour_Lvl', 'LandSlope_Gtl', 'LandSlope_Mod', 'LandSlope_Sev', 'HouseStyle_1.5Fin', 'HouseStyle_1.5Unf', 'HouseStyle_1Story', 'HouseStyle_2.5Fin', 'HouseStyle_2.5Unf', 'HouseStyle_2Story', 'HouseStyle_SFoyer', 'HouseStyle_SLvl', 'RoofStyle_Flat', 'RoofStyle_Gable', 'RoofStyle_Gambrel', 'RoofStyle_Hip', 'RoofStyle_Mansard', 'RoofStyle_Shed', 'MasVnrType_BrkCmn', 'MasVnrType_BrkFace', 'MasVnrType_None', 'MasVnrType_Stone', 'Foundation_BrkTil', 'Foundation_CBlock', 'Foundation_PConc', 'Foundation_Slab', 'Foundation_Stone', 'Foundation_Wood', 'BsmtQual_Ex', 'BsmtQual_Fa', 'BsmtQual_Gd', 'BsmtQual_TA', 'Heating_Floor', 'Heating_GasA', 'Heating_GasW', 'Heating_Grav', 'Heating_OthW', 'Heating_Wall', 'Functional_Maj1', 'Functional_Maj2', 'Functional_Min1', 'Functional_Min2', 'Functional_Mod', 'Functional_
# ...

# %%
# Make prediction
y_prediction = mlr.predict(data_valid)
y_prediction
# Out:
# array([244234.36555941, 147516.56602511,  89963.04099076, 226213.96535439,
#        103290.22325483,  89368.26327183, 233904.64597976, 113907.21217929,
#        552845.9953342 , 146779.8762888 , 254055.9852293 , 203197.18022905,
#        221225.78566836, 112955.65656514, 120237.13233618, 152844.6954754 ,
#        209240.05968158, 128998.68771035, 143808.83017153, 131249.26629773,
#        144705.70606314, 143257.16858987,  86685.84774022, 175009.01646934,
#        198257.86204386, 149494.9878007 , 188242.9099546 ,  85414.47945406,
#        320144.59178825, 115947.85505739, 211548.64228201, 197296.47777312,
#        141268.16860049, 256574.62055761, 364021.65113261, 173267.11556385,
#        283213.57944441, 121388.32399272, 233594.24014313, 343220.01865159,
#        225542.47371994, 114466.38125755, 190615.25486031, 328227.88879746,
#        316307.7037167 , 185501.82062168, 110102.15663764, 111636.07247894,
# ...

# %%
# Calculate RMSE
rmse = np.sqrt(mean_squared_error(target_valid, y_prediction))
print("RMSE: %s" % rmse)
# Out:
# RMSE: 45198.247154183795
